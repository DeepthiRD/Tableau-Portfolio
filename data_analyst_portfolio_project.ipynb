# %%
#https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_19288\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
# See the data,dtypes and feilds

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Clean up data

# %%
# Get only IND race

# %%
df1 = df[(df['Year of event'] == 2022)]

# %%
df1.head(10)
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153

# %%
df1[df1['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                            Event name  \
# 3138257           2022  12.03.2022    Griffith Park Trail Marathon (USA)
# 3138258           2022  12.03.2022    Griffith Park Trail Marathon (USA)
# 3138259           2022  12.03.2022    Griffith Park Trail Marathon (USA)
# 3138260           2022  12.03.2022    Griffith Park Trail Marathon (USA)
# 3138261           2022  12.03.2022    Griffith Park Trail Marathon (USA)
# ...                ...         ...                                   ...
# 3609628           2022  16.10.2022  Spooner's Cove 50 km Trail Run (USA)
# 3609629           2022  16.10.2022  Spooner's Cove 50 km Trail Run (USA)
# 3609630           2022  16.10.2022  Spooner's Cove 50 km Trail Run (USA)
# 3609631           2022  16.10.2022  Spooner's Cove 50 km Trail Run (USA)
# 3609632           2022  16.10.2022  Spooner's Cove 50 km Trail Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138257                  50km                         76           4:01:13 h
# 3138258                  50km                         76           4:04:07 h
# 3138259                  50km                         76           4:27:18 h
# 3138260                  50km                         76           4:28:32 h
# 3138261                  50km                         76           4:40:49 h
# ...                       ...                        ...                 ...
# 3609628                  50km                         26           7:25:57 h
# 3609629                  50km                         26           7:31:38 h
# 3609630                  50km                         26           7:33:37 h
# 3609631                  50km                         26           7:33:53 h
# 3609632                  50km                         26           7:55:06 h
#
#                  Athlete club Athlete country  Athlete year of birth  \
# 3138257     *Coto De Caza, CA             USA                 1972.0
# 3138258                   NaN             USA                 1963.0
# 3138259      *Los Angeles, CA             USA                 1980.0
# 3138260         *Stoneham, MA             USA                 2000.0
# 3138261      *Los Angeles, CA             USA                 1981.0
# ...                       ...             ...                    ...
# 3609628          *Fernley, NV             USA                 1970.0
# 3609629     *Agoura Hills, CA             USA                 1973.0
# 3609630    *Scotts Valley, CA             USA                 1955.0
# 3609631           *Sylmar, CA             USA                 1981.0
# 3609632  *Santa Margarita, CA             USA                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138257              M                  M45                12.437      202038
# 3138258              M                  M55                12.289       55422
# 3138259              M                  M40                11.223      655829
# 3138260              M                 MU23                11.172      596371
# 3138261              M                  M40                10.683      361178
# ...                ...                  ...                   ...         ...
# 3609628              M                  M50                 6.727      524041
# 3609629              M                  M45                 6.643      894553
# 3609630              M                  M65                 6.614       33502
# 3609631              F                  W40                  6.61      984741
# 3609632              M                  M40                 6.314     1044687
#
# [91699 rows x 13 columns]

# %%
df1[df1['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# ...                ...         ...                                    ...
# 3609801           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609802           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609803           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609804           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609805           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# ...                       ...                        ...                 ...
# 3609801                  50mi                         35          11:16:08 h
# 3609802                  50mi                         35          11:27:05 h
# 3609803                  50mi                         35          11:46:34 h
# 3609804                  50mi                         35          11:55:29 h
# 3609805                  50mi                         35          12:14:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# ...                      ...             ...                    ...
# 3609801  *Peachtree City, GA             USA                 1968.0
# 3609802         *Newport, PA             USA                 1959.0
# 3609803      *Flemington, NJ             USA                 1955.0
# 3609804       *Arlington, VA             USA                 1965.0
# 3609805       *Johnstown, PA             USA                 1981.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# ...                ...                  ...                   ...         ...
# 3609801              M                  M50                 7.141     1044739
# 3609802              M                  M60                 7.027       50971
# 3609803              F                  W65                 6.833       73152
# 3609804              M                  M55                 6.748      970133
# 3609805              F                  W40                 6.575      723380
#
# [111250 rows x 13 columns]

# %%
df1= df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2022)]

# %%
df1.head(10)
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153

# %%
df1.shape
# Out:
# (111250, 13)

# %%
df1.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                      bool
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.head(10)
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='IND']
# Out:
#          Year of event     Event dates                       Event name  \
# 3153957           2022  19.-20.02.2022         Delta 50 Ultra Run (IND)
# 3153958           2022  19.-20.02.2022         Delta 50 Ultra Run (IND)
# 3153959           2022  19.-20.02.2022         Delta 50 Ultra Run (IND)
# 3153960           2022  19.-20.02.2022         Delta 50 Ultra Run (IND)
# 3153961           2022  19.-20.02.2022         Delta 50 Ultra Run (IND)
# ...                ...             ...                              ...
# 3517261           2022      18.09.2022  Mukteshwar Ultra Marathon (IND)
# 3517262           2022      18.09.2022  Mukteshwar Ultra Marathon (IND)
# 3517263           2022      18.09.2022  Mukteshwar Ultra Marathon (IND)
# 3517264           2022      18.09.2022  Mukteshwar Ultra Marathon (IND)
# 3517265           2022      18.09.2022  Mukteshwar Ultra Marathon (IND)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3153957                  50km                          7           6:01:01 h
# 3153958                  50km                          7           6:05:05 h
# 3153959                  50km                          7           6:05:34 h
# 3153960                  50km                          7           6:25:57 h
# 3153961                  50km                          7           6:38:40 h
# ...                       ...                        ...                 ...
# 3517261                  50km                         25           7:46:00 h
# 3517262                  50km                         25           7:47:00 h
# 3517263                  50km                         25           8:10:00 h
# 3517264                  50km                         25           8:11:00 h
# 3517265                  50km                         25           8:12:00 h
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 3153957          NaN             IND                 1985.0              M
# 3153958          NaN             IND                 1983.0              M
# 3153959          NaN             IND                    NaN              F
# 3153960          NaN             IND                    NaN              M
# 3153961          NaN             IND                    NaN              F
# ...              ...             ...                    ...            ...
# 3517261          NaN             IND                 1975.0              M
# 3517262          NaN             IND                 1986.0              M
# 3517263          NaN             IND                 1985.0              M
# 3517264          NaN             IND                 1996.0              M
# 3517265          NaN             IND                 1987.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 3153957                  M35                  8.31      810295
# 3153958                  M35                 8.217       68767
# 3153959                  NaN                 8.206      950414
# 3153960                  NaN                 7.773      950415
# 3153961                  NaN                 7.525      950416
# ...                      ...                   ...         ...
# 3517261                  M45                 6.438     1025337
# 3517262                  M35                 6.424      322344
# 3517263                  M35                 6.122     1025338
# 3517264                  M23                  6.11     1025339
# 3517265                  M23                 6.098     1025340
#
# [273 rows x 13 columns]

# %%
#Combine all of the filters together

# %%
df2= df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2022)&(df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='USA')]

# %%
df2.shape
# Out:
# (58600, 13)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153

# %%
#remove USA

# %%
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_19288\2517910487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                        Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153

# %%
df2['Athlete age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_19288\3561433967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete age'] = 2020 - df2['Athlete year of birth']

# %%
df2.head(10)
# Out:
#          Year of event Event dates                        Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153
#
#          Athlete age
# 3138208         26.0
# 3138209         30.0
# 3138210         41.0
# 3138211         26.0
# 3138212         23.0
# 3138213         29.0
# 3138214         46.0
# 3138215         29.0
# 3138216         29.0
# 3138217         48.0

# %%
df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# 3138208     7:53:36
# 3138209     8:14:24
# 3138210     8:19:16
# 3138211     8:23:49
# 3138212     8:41:37
#              ...
# 3609801    11:16:08
# 3609802    11:27:05
# 3609803    11:46:34
# 3609804    11:55:29
# 3609805    12:14:15
# Name: Athlete performance, Length: 58600, dtype: object

# %%
df2.head(10)
# Out:
#          Year of event Event dates                        Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# 3138213                  50mi                         49           8:51:32 h
# 3138214                  50mi                         49           9:03:32 h
# 3138215                  50mi                         49           9:33:18 h
# 3138216                  50mi                         49           9:38:25 h
# 3138217                  50mi                         49           9:49:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153
#
#          Athlete age
# 3138208         26.0
# 3138209         30.0
# 3138210         41.0
# 3138211         26.0
# 3138212         23.0
# 3138213         29.0
# 3138214         46.0
# 3138215         29.0
# 3138216         29.0
# 3138217         48.0

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_19288\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                        Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49             7:53:36
# 3138209                  50mi                         49             8:14:24
# 3138210                  50mi                         49             8:19:16
# 3138211                  50mi                         49             8:23:49
# 3138212                  50mi                         49             8:41:37
# 3138213                  50mi                         49             8:51:32
# 3138214                  50mi                         49             9:03:32
# 3138215                  50mi                         49             9:33:18
# 3138216                  50mi                         49             9:38:25
# 3138217                  50mi                         49             9:49:15
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# 3138213       *Arlington, VA             USA                 1991.0
# 3138214        *New Hill, NC             USA                 1974.0
# 3138215      *Washington, DC             USA                 1991.0
# 3138216         *Weirton, WV             USA                 1991.0
# 3138217  *Stone Mountain, GA             USA                 1972.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# 3138213              M                  M23                 9.083      607025
# 3138214              M                  M45                 8.883       25563
# 3138215              M                  M23                 8.421      591057
# 3138216              M                  M23                 8.347      741573
# 3138217              M                  M45                 8.194         153
#
#          Athlete age
# 3138208         26.0
# 3138209         30.0
# 3138210         41.0
# 3138211         26.0
# 3138212         23.0
# 3138213         29.0
# 3138214         46.0
# 3138215         29.0
# 3138216         29.0
# 3138217         48.0

# %%
#drop columns : Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete age                  float64
# dtype: object

# %%
df2 = df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis = 1)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                        Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138213           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138214           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138215           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138216           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3138217           2022  12.03.2022  Bel Monte 50 Mile Endurance Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49             7:53:36
# 3138209                  50mi                         49             8:14:24
# 3138210                  50mi                         49             8:19:16
# 3138211                  50mi                         49             8:23:49
# 3138212                  50mi                         49             8:41:37
# 3138213                  50mi                         49             8:51:32
# 3138214                  50mi                         49             9:03:32
# 3138215                  50mi                         49             9:33:18
# 3138216                  50mi                         49             9:38:25
# 3138217                  50mi                         49             9:49:15
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete age
# 3138208              M                10.194      839364         26.0
# 3138209              M                 9.765      366598         30.0
# 3138210              M                  9.67      553476         41.0
# 3138211              M                 9.583      807555         26.0
# 3138212              M                 9.256      947348         23.0
# 3138213              M                 9.083      607025         29.0
# 3138214              M                 8.883       25563         46.0
# 3138215              M                 8.421      591057         29.0
# 3138216              M                 8.347      741573         29.0
# 3138217              M                 8.194         153         48.0

# %%
#clean up nulls

# %%
df2.isna().sum()
# Out:
# Year of event                   0
# Event dates                     0
# Event name                      0
# Event distance/length           0
# Event number of finishers       0
# Athlete performance             0
# Athlete gender                  0
# Athlete average speed           0
# Athlete ID                      0
# Athlete age                  1788
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (56812, 10)

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                        Event name  \
# 0               2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 1               2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 2               2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 3               2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# 4               2022  12.03.2022  Bel Monte 50 Mile Endurance Run
# ...              ...         ...                               ...
# 56807           2022  16.10.2022     Tussey Mountainback 50 Miler
# 56808           2022  16.10.2022     Tussey Mountainback 50 Miler
# 56809           2022  16.10.2022     Tussey Mountainback 50 Miler
# 56810           2022  16.10.2022     Tussey Mountainback 50 Miler
# 56811           2022  16.10.2022     Tussey Mountainback 50 Miler
#
#       Event distance/length  Event number of finishers Athlete performance  \
# 0                      50mi                         49             7:53:36
# 1                      50mi                         49             8:14:24
# 2                      50mi                         49             8:19:16
# 3                      50mi                         49             8:23:49
# 4                      50mi                         49             8:41:37
# ...                     ...                        ...                 ...
# 56807                  50mi                         35            11:16:08
# 56808                  50mi                         35            11:27:05
# 56809                  50mi                         35            11:46:34
# 56810                  50mi                         35            11:55:29
# 56811                  50mi                         35            12:14:15
#
#       Athlete gender Athlete average speed  Athlete ID  Athlete age
# 0                  M                10.194      839364         26.0
# 1                  M                 9.765      366598         30.0
# 2                  M                  9.67      553476         41.0
# 3                  M                 9.583      807555         26.0
# 4                  M                 9.256      947348         23.0
# ...              ...                   ...         ...          ...
# 56807              M                 7.141     1044739         52.0
# 56808              M                 7.027       50971         61.0
# 56809              F                 6.833       73152         65.0
# 56810              M                 6.748      970133         55.0
# 56811              F                 6.575      723380         39.0
#
# [56812 rows x 10 columns]

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete age                  float64
# dtype: object

# %%
df2['Athlete age'] = df2['Athlete age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete age                    int32
# dtype: object

# %%
#rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#Athlete age                    int32

# %%
df2 = df2.rename(columns = {'Year of event':'year',
                            'Event dates':'race_day',
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_number_of_finishers',
                            'Athlete performance':'athlete_performance',
                            'Atlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_average_speed',
                            'Athlete ID':'athlete_id',
                            'Athlete age':'athlete_age'})

# %%
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# atlete_gender                object
# athlete_average_speed       float64
# athlete_id                    int64
# athlete_age                   int32
# dtype: object

# %%
#reorder columns

# %%
df3 = df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','atlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day                         race_name race_length  \
# 3138208  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138209  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138210  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138211  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138212  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
#
#          race_number_of_finishers  athlete_id atlete_gender  athlete_age  \
# 3138208                        49      839364             M           26
# 3138209                        49      366598             M           30
# 3138210                        49      553476             M           41
# 3138211                        49      807555             M           26
# 3138212                        49      947348             M           23
#
#         athlete_performance  athlete_average_speed
# 3138208             7:53:36                 10.194
# 3138209             8:14:24                  9.765
# 3138210             8:19:16                  9.670
# 3138211             8:23:49                  9.583
# 3138212             8:41:37                  9.256

# %%
df3 = df3.rename(columns={'atlete_gender':'athlete_gender'})

# %%
df3.head()
# Out:
#            race_day                         race_name race_length  \
# 3138208  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138209  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138210  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138211  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138212  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 3138208                        49      839364              M           26
# 3138209                        49      366598              M           30
# 3138210                        49      553476              M           41
# 3138211                        49      807555              M           26
# 3138212                        49      947348              M           23
#
#         athlete_performance  athlete_average_speed
# 3138208             7:53:36                 10.194
# 3138209             8:14:24                  9.765
# 3138210             8:19:16                  9.670
# 3138211             8:23:49                  9.583
# 3138212             8:41:37                  9.256

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3,x = 'race_length',hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])

# %%
sns.violinplot(data = df3,x='race_length',y='athlete_average_speed',hue='athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3,x='athlete_age',y='athlete_average_speed',hue = 'athlete_gender')

# %%
#questions I want to find out from the data

# %%
df3.dtypes
# Out:
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_id                    int64
# athlete_gender               object
# athlete_age                   int32
# athlete_performance          object
# athlete_average_speed       float64
# dtype: object

# %%
#race_day
#race_name
#race_length
#race_number_of_finishers
#athlete_id
#athlete_gender
#athlete_age
#athlete_performance
#athlete_average_speed

# %%
#Difference in speed for the 50km,50 mi male to female

# %%
df3.groupby(['race_length','athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 6.966948
#              M                 7.562757
#              X                 8.444000
# 50mi         F                 6.779096
#              M                 7.218046
# Name: athlete_average_speed, dtype: float64

# %%
#what age groups are the best in the 50mi Race(20+race min)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending = False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 17           7.781079     38
# 24           7.750676    262
# 18           7.633224     67
# 30           7.560600    418
# 22           7.526565    186
# 23           7.477597    206
# 26           7.428883    325
# 29           7.424462    394
# 25           7.418414    256
# 19           7.400543     92
# 20           7.391286    112
# 32           7.388895    457
# 27           7.352136    367
# 28           7.347627    367
# 35           7.345280    517
# 21           7.306007    152
# 36           7.257154    507
# 33           7.220825    435
# 34           7.211051    469
# 37           7.184612    529
# 38           7.174552    525
# 41           7.111561    467
# 42           7.096572    467
# 31           7.087146    417
# 47           7.053153    339
# 40           6.996457    541
# 44           6.989770    435
# 16           6.982250     20
# 39           6.979280    557
# 55           6.955940    166
# 43           6.923007    436
# 46           6.884575    369
# 51           6.871323    294
# 45           6.853639    404
# 49           6.791651    307
# 56           6.761993    139
# 52           6.761831    255
# 50           6.739696    283
# 48           6.724938    384
# 59           6.656684     95
# 57           6.649380    150
# 60           6.645245     98
# 54           6.619654    182
# 53           6.590199    211
# 58           6.514132    144
# 61           6.499551     89
# 62           6.263042     71
# 64           6.120250     40
# 65           6.089679     28
# 63           5.990196     51
# 67           5.976714     28
# 66           5.758423     26

# %%
#what age groups are the worst in the 50mi Race(20+race min) (show 20)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending = True).query('count>9')
# Out:
#                  mean  count
# athlete_age
# 72           5.426800     10
# 71           5.486500     16
# 66           5.758423     26
# 68           5.958667     18
# 67           5.976714     28
# 63           5.990196     51
# 69           6.078100     10
# 65           6.089679     28
# 64           6.120250     40
# 70           6.129071     14
# 62           6.263042     71
# 61           6.499551     89
# 58           6.514132    144
# 53           6.590199    211
# 54           6.619654    182
# 60           6.645245     98
# 57           6.649380    150
# 59           6.656684     95
# 48           6.724938    384
# 50           6.739696    283
# 52           6.761831    255
# 56           6.761993    139
# 49           6.791651    307
# 45           6.853639    404
# 51           6.871323    294
# 46           6.884575    369
# 43           6.923007    436
# 55           6.955940    166
# 39           6.979280    557
# 16           6.982250     20
# 44           6.989770    435
# 40           6.996457    541
# 47           7.053153    339
# 31           7.087146    417
# 42           7.096572    467
# 15           7.107600     10
# 41           7.111561    467
# 38           7.174552    525
# 37           7.184612    529
# 34           7.211051    469
# 33           7.220825    435
# 36           7.257154    507
# 21           7.306007    152
# 35           7.345280    517
# 28           7.347627    367
# 27           7.352136    367
# 32           7.388895    457
# 20           7.391286    112
# 19           7.400543     92
# 25           7.418414    256
# 29           7.424462    394
# 26           7.428883    325
# 23           7.477597    206
# 22           7.526565    186
# 30           7.560600    418
# 18           7.633224     67
# 24           7.750676    262
# 17           7.781079     38

# %%
#Seasons for Data -> Slower in Summer than Winter?

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3['race_season'] = df3['race_month'].apply(lambda x:'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df3.head()
# Out:
#            race_day                         race_name race_length  \
# 3138208  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138209  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138210  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138211  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
# 3138212  12.03.2022  Bel Monte 50 Mile Endurance Run         50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 3138208                        49      839364              M           26
# 3138209                        49      366598              M           30
# 3138210                        49      553476              M           41
# 3138211                        49      807555              M           26
# 3138212                        49      947348              M           23
#
#         athlete_performance  athlete_average_speed  race_month race_season
# 3138208             7:53:36                 10.194           3      Spring
# 3138209             8:14:24                  9.765           3      Spring
# 3138210             8:19:16                  9.670           3      Spring
# 3138211             8:23:49                  9.583           3      Spring
# 3138212             8:41:37                  9.256           3      Spring

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Winter       7.447456  11606
# Fall         7.313487  16796
# Spring       7.307005  17056
# Summer       7.055710  11354

# %%
#50 miler only

# %%
df3.query('race_length == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Fall         7.388951   3913
# Spring       7.133504   4098
# Winter       6.911593   3268
# Summer       6.824000   3004
